# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("cars.csv")
data.head()
# Out:
#     mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0  14.0          8         350  165      4209          12  1972       US.
# 1  31.9          4          89   71      1925          14  1980   Europe.
# 2  17.0          8         302  140      3449          11  1971       US.
# 3  15.0          8         400  150      3761          10  1971       US.
# 4  30.5          4          98   63      2051          17  1978       US.

# %%
data.info()  # summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
data.dtypes
# Out:
# mpg            float64
# cylinders        int64
# cubicinches     object
# hp               int64
# weightlbs       object
# time-to-60       int64
# year             int64
# brand           object
# dtype: object

# %%
# As cubicinches and weightlbs are not in proper datatype we need to change their datatypes.
# .astype()
# pd.to_numeric()


data["cubicinches"] = pd.to_numeric(data["cubicinches"], errors = "coerce")
data["weightlbs"] = pd.to_numeric(data["weightlbs"], errors = "coerce")


# ? -> NAN
# all non-convertable values into NAN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# Question 1 Create scatter plots for the following data, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# 1.‘hp’ and ‘mpg’.
#
# 2.‘hp’ and ‘time-to-60’.
#
# 3.‘hp’ and ‘weightlbs’.
#
# 4.‘hp’ and ‘cylinders’.
#
# 5.Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand.

# %%
#example
x = [5,7,8,2,3,4]
y = [2,3,5,7,3,2]

sns.scatterplot(x = x, y = y,color = 'red')
plt.title("Scatter plot")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
# subplots

fig = plt.subplots(2,2, figsize = (15,10))

# %%
fig = plt.subplots(2,2,figsize=(15,10))


plt.subplot(2,2,1)
sns.scatterplot(x = data['mpg'], y = data['hp'], data= data)
plt.title('MPG to HP data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Horsepower")

plt.subplot(2,2,2)
sns.scatterplot(x=data['hp'], y=data['time-to-60'], data=data)
plt.title('HP to Time-to-60 data')
plt.xlabel("Horsepower")
plt.ylabel("Time-to-60")

plt.subplot(2,2,3)
sns.scatterplot(x=data['hp'], y=data['weightlbs'], data=data)
plt.title('HP to Weight Data')
plt.xlabel("Horsepower")
plt.ylabel("Weightlbs")


plt.subplot(2,2,4)
sns.scatterplot(x=data['hp'], y=data['cylinders'], data=data)
plt.title('HP to Cylinders data')
plt.xlabel("Horsepower")
plt.ylabel("No of Cylinders")


plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
fig = plt.subplots(2,2, figsize=(20,10))


plt.subplot(2,2,1)
sns.scatterplot(x=data['mpg'], y=data['hp'],hue=data['brand'], data=data)

plt.subplot(2,2,2)
sns.scatterplot(x=data['hp'], y=data['time-to-60'], hue=data['brand'], data=data)

plt.subplot(2,2,3)
sns.scatterplot(x=data['hp'], y=data['mpg'], hue=data['brand'], data= data)

plt.subplot(2,2,4)
sns.scatterplot(x=data['mpg'], y=data['weightlbs'], hue=data['brand'], data=data)
# Out:
# <Axes: xlabel='mpg', ylabel='weightlbs'>

# %% [markdown]
# Question 2
# Create bar plots for the following, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# 1. Cylinders and Horsepower, Cylinders and miles per gallon, Cylinders and weight.
#
# 2. Year and time-to-60, Year and miles per gallon, Year and horsepower.
#
# 3. Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.
#
# 4. Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, for each brand.

# %%
#Example
x_value = [5,7,8,2,3,4]
y_value = [2,3,5,7,3,2]

sns.barplot(x = x_value ,y = y_value )
plt.title("Scatter plot")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
fix = plt.subplots(2,2,figsize=(15,10))
plt.subplot(2,2,1)
sns.barplot( x =  data['cylinders'], y = data['hp'], data=data, hue=data['brand'])
plt.title('hp vs cylinders')
plt.xlabel('hp')
plt.ylabel('cylinders')


plt.subplot(2,2,2)
sns.barplot(x = data['cylinders'], y = data['mpg'], data=data, hue=data['brand'])
plt.title('cylinders vs mpg')
plt.xlabel('cylinders')
plt.ylabel('mpg')

plt.subplot(2,2,3)
sns.barplot(x = data['cylinders'], y = data['weightlbs'], data=data, hue=data['brand'])
plt.title('cylinders vs weightlbs')
plt.xlabel('hp')
plt.ylabel('weightlbs')

plt.subplot(2,2,4)
sns.barplot(x = data['cylinders'],y =  data['time-to-60'], data=data, hue=data['brand'])
plt.title('cylinders vs time-to-60')
plt.ylabel('time-to-60')
plt.xlabel('cylinders')
# Out:
# Text(0.5, 0, 'cylinders')

# %% [markdown]
# Question 3
# Create box plots for the following:
#
# 1.Create box plots for the columns hp, mpg, time-to-60, and weight lbs.

# %%
# Example


data1 = np.random.normal(100,20,200)
fig = plt.figure(figsize = (10,7))
plt.boxplot(data1)
plt.show()

# %%
data1
# Out:
# array([144.85279936, 101.35884336, 115.39465104,  92.3141755 ,
#        105.71510455, 107.5953898 ,  86.64325986,  74.07420467,
#        107.47520335, 106.86578706, 101.13458916, 111.3350756 ,
#        130.52674803, 100.57130687,  83.07092546, 122.93737775,
#        110.46565876, 111.88799094,  83.30654655, 111.43094052,
#         90.92507907,  98.79579592,  92.17902923,  86.83743342,
#         59.34421478,  97.67467689, 101.16978556,  95.38007745,
#        107.15866312,  78.15953853, 119.96772295, 113.54303302,
#        116.06522551,  95.3504063 ,  88.85344484,  91.62235622,
#         93.50473802,  70.91935656, 114.2276053 , 128.68011702,
#         84.69230318,  81.73981331, 126.46755125,  96.56840882,
#        106.81750021,  67.1362287 ,  93.3283237 ,  99.72805818,
#         89.70072049, 132.32837973,  72.33270851,  65.79309818,
#         79.51803191,  83.23893201, 109.51521614,  65.42376518,
#        114.96531718, 110.56315546,  85.17314702, 115.85924047,
#         89.68983393, 107.70495195, 122.27002437,  93.22705437,
#        131.04179838,  80.53333891, 117.55530979,  81.38889729,
#        126.17010486, 143.07827973,  81.98462841,  70.40306312,
#         74.75558034, 121.64951516,  85.85179873,  75.44269327,
#        114.8622294 ,  83.92955311,  76.27215175, 116.87732582,
#         73.66117808,  67.75836699,  87.90704412,  67.2293529 ,
#         99.96644278, 106.56437374, 127.41434863,  69.28249331,
#        120.61452238, 122.10829563,  98.13348379, 100.78969523,
#        111.85629058, 110.30715158, 123.87679765,  67.95665569,
#         98.74044242, 118.68786659,  91.99705615,  93.34620756,
#        111.12884207, 134.56825899, 100.70672437,  98.1077969 ,
#        110.1543068 , 103.48991056, 105.46377814, 100.02607653,
#        107.39288655, 125.66514924,  63.39300188, 110.47962979,
#        123.49358356, 102.29887541,  75.6461506 , 108.39813   ,
#         30.45309573,  90.02167488,  91.77403464,  98.51355834,
#         98.91457531, 103.15786658,  79.95078226, 102.43190154,
#        127.22322729, 135.50778976,  68.16988055, 122.02270586,
#         92.51350463,  88.27989612,  72.51360298,  99.36032346,
#         97.12695579,  83.24417514, 102.12497171,  90.90336707,
#         95.22390976, 101.40978344, 117.96128419, 120.2796918 ,
#        113.90768902,  56.95173017,  52.60981693, 108.83598477,
#         77.9208905 ,  96.71606869,  92.84208885,  77.09317018,
#         76.26150849, 119.76685088,  96.25143948,  83.33574789,
#        107.31039915,  85.99778495,  84.49074329,  99.17284415,
#         79.41256667, 152.25123243, 102.72343369,  84.52509808,
#         79.97094348,  81.83523121, 121.94539439,  62.51415898,
#        104.33871963,  79.24726331,  78.10723993,  97.23932931,
#         89.6902865 , 119.17062727,  83.72908112,  81.12451471,
#         70.6978175 ,  85.72950258,  67.83926034,  69.07063932,
#        105.52390651,  79.97697667, 119.72014857, 100.1128428 ,
#         72.03711301,  96.8612586 ,  83.52043485, 111.01557717,
#        106.8981124 , 129.6322976 ,  91.88062005,  89.8932796 ,
#         91.72189661,  87.90074877, 104.93601536,  86.37678322,
#        104.29088611, 105.10472351, 102.68765608,  96.92902087,
#         77.89526757,  94.00329012,  76.72051204,  74.98397949])

# %%
fig = plt.subplots(2,2, figsize=(20,10))

plt.subplot(2,2,1)
sns.boxplot(data['hp'])
plt.title("Horsepower")

plt.subplot(2,2,2)
sns.boxplot(data['mpg'])
plt.title("Miles Per Gallon")

plt.subplot(2,2,3)
sns.boxplot(data['weightlbs'])
plt.title("Weightlbs")


plt.subplot(2,2,4)
sns.boxplot(data['time-to-60'])
plt.title("time-to-60")
# Out:
# Text(0.5, 1.0, 'time-to-60')

# %% [markdown]
# Question 4
#
# Create pair plots for the entire data to study various patterns in the data.

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = 'brand')

# %% [markdown]
# #Question 5
#
# Create a heatmap for the entire data to study correlation between each of the columns.

# %%
#example
data2 = np.random.randint(1,100,size= (10,10))
hm = sns.heatmap(data = data2)

# %%
x = data.corr(numeric_only = True)
x
# Out:
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.803964 -0.774905  -0.825234
# cylinders   -0.776710   1.000000     0.951452  0.845155   0.896093
# cubicinches -0.803964   0.951452     1.000000  0.906902   0.930027
# hp          -0.774905   0.845155     0.906902  1.000000   0.861028
# weightlbs   -0.825234   0.896093     0.930027  0.861028   1.000000
# time-to-60   0.509070  -0.578161    -0.613199 -0.744873  -0.480772
# year         0.550441  -0.322239    -0.350293 -0.383869  -0.281119
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# cubicinches   -0.613199 -0.350293
# hp            -0.744873 -0.383869
# weightlbs     -0.480772 -0.281119
# time-to-60     1.000000  0.312311
# year           0.312311  1.000000

# %%
sns.heatmap(x, annot = True , cmap ="Reds")
# Out:
# <Axes: >

# %% [markdown]
# Question 6
# Create a histogram for the following:
#
# Each column in the data to understand the distribution of the data.
# Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand.

# %%
fig, axes = plt.subplots(3,2, figsize=(20,10))


plt.subplot(3,2,1)
sns.histplot(x=data['hp'], hue=data['brand'])

plt.subplot(3,2,2)
sns.histplot(x=data['mpg'], hue=data['brand'])

plt.subplot(3,2,3)
sns.histplot(x=data['weightlbs'], hue=data['brand'])

plt.subplot(3,2,4)
sns.histplot(x=data['time-to-60'], hue=data['brand'])

plt.subplot(3,2,5)
sns.histplot(x=data['cubicinches'], hue=data['brand'])

plt.subplot(3,2,6)
sns.histplot(x=data['year'], hue=data['brand'])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
import seaborn as sns

# %% [markdown]
# #Question 7
# Create line plots for the following:
#
# Create a line plot for the columns hp, mpg, time-to-60, weight lbs, where each line is a different color. [red, green, blue, orange].

# %%
  #Example
x = [5,7,8,2,3,4]
y = [2,3,5,7,3,2]
sns.lineplot(x= x,y =y)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2,2, figsize=(20,10))


plt.subplot(2,2,1)
sns.lineplot(data= data, x='hp', y='mpg')

plt.subplot(2,2,2)
sns.lineplot(data= data, x='hp', y='time-to-60')

plt.subplot(2,2,3)
sns.lineplot(data= data, x='mpg', y='time-to-60')

plt.subplot(2,2,4)
sns.lineplot(data= data, x='hp', y='weightlbs')

plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
plt.plot(data["hp"], color = "red", label = "hp")
plt.plot(data["mpg"], color = "green" , label = "mpg")

# %% [markdown]
# Question 8
# Create a pie chart for the following columns and their distribution in the data:
#
# Brands
#
# Cylinders

# %%
# this is home work questions
